# %% [markdown]
# #Automatic Brain Tumor Detection and Semantic Segmentation Using U-Net Loss Jacard Metric Iou
# Mohammad Reza Tabrizi
#
# #Importar dados
# ##A seguinte função auxilia na importação dos dados recolhidos dos vários repositórios, associando a respetiva label aos mesmos. Os dados são convertidos em arrays:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-625b638a-9ec6-4195-a5cc-8f14a50c7d1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-625b638a-9ec6-4195-a5cc-8f14a50c7d1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lgg-mri-segmentation.zip to lgg-mri-segmentation (1).zip

# %%
import zipfile
import io
data = zipfile.ZipFile(io.BytesIO(uploaded['lgg-mri-segmentation.zip']), 'r')
data.extractall()

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

import cv2
from tqdm import tqdm
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# # Importar dados
# ### A seguinte função auxilia na importação dos dados recolhidos dos vários repositórios, associando a respetiva label aos mesmos. Os dados são convertidos em arrays:

# %%
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# %%
train_files = []
mask_files = glob('/content/lgg-mri-segmentation/kaggle_3m/*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_14.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_21.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_16.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_1.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_31.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_18.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_20.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_15.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_30.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_4.tif']
# ['/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_14_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_21_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_16_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_1_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_31_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_18_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_20_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_15_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_30_mask.tif', '/content/lgg-mri-segmentation/kaggle_3m/TCGA_DU_A5TW_19980228/TCGA_DU_A5TW_19980228_4_mask.tif']

# %%
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})

# %%
df.head()
# Out:
#                                             filename                                               mask
# 0  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 1  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 2  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 3  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...
# 4  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...  /content/lgg-mri-segmentation/kaggle_3m/TCGA_D...

# %%
X_train = np.zeros((len(df), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(df), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

# %%
for i in tqdm(range (len(df))):
    img_path=train_files[i]
    img=cv2.imread(img_path)[:,:,:IMG_CHANNELS] 
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[i] = img
    msk_path=mask_files[i]
    mask_ =cv2.imread(msk_path)
    mask_ = rgb2gray(mask_)
    mask_.shape
    mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                              preserve_range=True), axis=-1)
    Y_train[i] = mask_
# Out:
# 100%|██████████| 3929/3929 [00:56<00:00, 69.06it/s]

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (3929, 128, 128, 3)
# (3929, 128, 128, 1)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_train, Y_train, test_size=0.1, random_state=42)
print(X_train1.shape)
print(X_test1.shape)
# Out:
# (3536, 128, 128, 3)
# (393, 128, 128, 3)

# %% [markdown]
# # Sanety check, View few Images

# %%
image_number = random.randint(0,len(X_train1))
plt.figure(figsize=(12,6))
plt.subplot(121)
imshow(X_train1[image_number])
plt.subplot(122)
imshow(np.squeeze(y_train1[image_number]))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #As funções seguintes apresentam  configurações de redes neuronais UNet, a testar nas secções seguintes:

# %% [markdown]
# ##Função de Jacard

# %%
smooth=0.000001
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    intersection=K.sum(y_truef* y_predf)
    return((2.* intersection + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))
def dice_coef_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return 1 -dice_coef(y_true, y_pred)

# %%
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)


def jacard_coef_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return -jacard_coef(y_true, y_pred)  # -1 ultiplied as we want to minimize this value as loss function

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

def dice_coef_loss(y_true, y_pred):
  y_true = tf.cast(y_true, tf.float32)
  y_pred = tf.cast(y_pred, tf.float32)
  return 1 -dice_coef(y_true, y_pred)

# %%
def dice_coef(y_true, y_pred, smooth=0.01):
  intersection = K.sum(y_true * y_pred, axis=[1,2,3])
  union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
  dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
  return dice

def dice_coef_loss(y_true, y_pred):
  y_true = tf.cast(y_true, tf.float32)
  y_pred = tf.cast(y_pred, tf.float32)
  return 1 -dice_coef(y_true, y_pred)

# %%
smooth=0.0001
#smooth=1.
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %%
inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255)(inputs)

#Contraction path
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)
 
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)
 
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)
 
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
c5 = tf.keras.layers.Dropout(0.3)(c5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

#Expansive path 
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
 
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
 
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
 
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
 
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)
 
model_jacard_lr = tf.keras.Model(inputs=[inputs], outputs=[outputs])
opt = tf.keras.optimizers.Adam(learning_rate=0.0001,epsilon=1e-07)
model_jacard_lr.compile(optimizer=opt,loss = [dice_coef_loss], metrics=[iou])

model_jacard_lr.summary()
tf.keras.utils.plot_model(model_jacard_lr, "simple_unet_model_jacard.png", show_shapes = True)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 128, 128, 3)  0           input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 128, 128, 16) 448         lambda_8[0][0]
# __________________________________________________________________________________________________
# dropout_72 (Dropout)            (None, 128, 128, 16) 0           conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 128, 128, 16) 2320        dropout_72[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 64, 64, 16)   0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 64, 64, 32)   4640        max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 64, 64, 32)   0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 64, 64, 32)   9248        dropout_73[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 32, 32, 32)   0           conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 32, 32, 64)   0           conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 64)   36928       dropout_74[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 16, 16, 64)   0           conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 16, 16, 128)  73856       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 16, 16, 128)  0           conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 16, 16, 128)  147584      dropout_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 8, 8, 128)    0           conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 8, 8, 256)    295168      max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 8, 8, 256)    0           conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 8, 8, 256)    590080      dropout_76[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 16, 16, 128)  131200      conv2d_161[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 16, 16, 256)  0           conv2d_transpose_32[0][0]
#                                                                  conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 16, 16, 128)  295040      concatenate_32[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 16, 16, 128)  0           conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 16, 16, 128)  147584      dropout_77[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 32, 32, 64)   32832       conv2d_163[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 32, 32, 128)  0           conv2d_transpose_33[0][0]
#                                                                  conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 32, 32, 64)   73792       concatenate_33[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 32, 32, 64)   0           conv2d_164[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 32, 32, 64)   36928       dropout_78[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_34 (Conv2DTran (None, 64, 64, 32)   8224        conv2d_165[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 64, 64, 64)   0           conv2d_transpose_34[0][0]
#                                                                  conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 64, 64, 32)   18464       concatenate_34[0][0]
# __________________________________________________________________________________________________
# dropout_79 (Dropout)            (None, 64, 64, 32)   0           conv2d_166[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 64, 64, 32)   9248        dropout_79[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 128, 128, 16) 2064        conv2d_167[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 128, 128, 32) 0           conv2d_transpose_35[0][0]
#                                                                  conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 128, 128, 16) 4624        concatenate_35[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 128, 128, 16) 0           conv2d_168[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 128, 128, 16) 2320        dropout_80[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 128, 128, 1)  17          conv2d_169[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Modelcheckpoint
checkpointer = tf.keras.callbacks.ModelCheckpoint('simple_unet_model_jacard_lr.h5', verbose=1, save_best_only=True)

callbacks = [
        tf.keras.callbacks.EarlyStopping(patience=100, monitor='val_loss'),
        tf.keras.callbacks.TensorBoard(log_dir='logs')]
        
History_model_jacard_lr = model_jacard_lr.fit(X_train1, y_train1,
                    batch_size= 16,
                    verbose= 1,
                    epochs= 100,
                    validation_data= (X_test1,y_test1),
                    shuffle=False,
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# 221/221 [==============================] - 8s 30ms/step - loss: -0.0602 - iou: 0.0322 - val_loss: -0.2284 - val_iou: 0.1318
# Epoch 2/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.3489 - iou: 0.2227 - val_loss: -0.5281 - val_iou: 0.3701
# Epoch 3/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.5780 - iou: 0.4233 - val_loss: -0.6328 - val_iou: 0.4705
# Epoch 4/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.6117 - iou: 0.4564 - val_loss: -0.6866 - val_iou: 0.5298
# Epoch 5/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.6502 - iou: 0.4961 - val_loss: -0.6886 - val_iou: 0.5332
# Epoch 6/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.6783 - iou: 0.5282 - val_loss: -0.7076 - val_iou: 0.5559
# Epoch 7/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7009 - iou: 0.5532 - val_loss: -0.7285 - val_iou: 0.5810
# Epoch 8/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.6974 - iou: 0.5513 - val_loss: -0.7413 - val_iou: 0.5990
# Epoch 9/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7178 - iou: 0.5758 - val_loss: -0.7411 - val_iou: 0.5984
# Epoch 10/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7427 - iou: 0.6060 - val_loss: -0.7471 - val_iou: 0.6066
# Epoch 11/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7595 - iou: 0.6258 - val_loss: -0.7654 - val_iou: 0.6276
# Epoch 12/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7678 - iou: 0.6361 - val_loss: -0.7572 - val_iou: 0.6178
# Epoch 13/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7846 - iou: 0.6554 - val_loss: -0.7876 - val_iou: 0.6586
# Epoch 14/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7712 - iou: 0.6413 - val_loss: -0.7914 - val_iou: 0.6626
# Epoch 15/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7933 - iou: 0.6667 - val_loss: -0.8142 - val_iou: 0.6933
# Epoch 16/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.7941 - iou: 0.6690 - val_loss: -0.8038 - val_iou: 0.6787
# Epoch 17/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8142 - iou: 0.6950 - val_loss: -0.8193 - val_iou: 0.6994
# Epoch 18/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8184 - iou: 0.7010 - val_loss: -0.8101 - val_iou: 0.6883
# Epoch 19/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8219 - iou: 0.7065 - val_loss: -0.8000 - val_iou: 0.6747
# Epoch 20/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8186 - iou: 0.7015 - val_loss: -0.8238 - val_iou: 0.7070
# Epoch 21/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8263 - iou: 0.7128 - val_loss: -0.8160 - val_iou: 0.6971
# Epoch 22/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8329 - iou: 0.7219 - val_loss: -0.8282 - val_iou: 0.7147
# Epoch 23/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8231 - iou: 0.7079 - val_loss: -0.8111 - val_iou: 0.6923
# Epoch 24/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8424 - iou: 0.7361 - val_loss: -0.8108 - val_iou: 0.6918
# Epoch 25/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8436 - iou: 0.7374 - val_loss: -0.8197 - val_iou: 0.7046
# Epoch 26/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8478 - iou: 0.7436 - val_loss: -0.8431 - val_iou: 0.7368
# Epoch 27/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8441 - iou: 0.7375 - val_loss: -0.8394 - val_iou: 0.7310
# Epoch 28/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8358 - iou: 0.7269 - val_loss: -0.7933 - val_iou: 0.6689
# Epoch 29/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8525 - iou: 0.7495 - val_loss: -0.8386 - val_iou: 0.7304
# Epoch 30/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8616 - iou: 0.7633 - val_loss: -0.8424 - val_iou: 0.7373
# Epoch 31/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8643 - iou: 0.7670 - val_loss: -0.8398 - val_iou: 0.7325
# Epoch 32/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8636 - iou: 0.7658 - val_loss: -0.8452 - val_iou: 0.7404
# Epoch 33/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8658 - iou: 0.7687 - val_loss: -0.8497 - val_iou: 0.7464
# Epoch 34/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8582 - iou: 0.7596 - val_loss: -0.8465 - val_iou: 0.7418
# Epoch 35/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8540 - iou: 0.7525 - val_loss: -0.8418 - val_iou: 0.7376
# Epoch 36/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8523 - iou: 0.7495 - val_loss: -0.8371 - val_iou: 0.7279
# Epoch 37/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8654 - iou: 0.7687 - val_loss: -0.8496 - val_iou: 0.7475
# Epoch 38/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8713 - iou: 0.7775 - val_loss: -0.8514 - val_iou: 0.7506
# Epoch 39/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8720 - iou: 0.7788 - val_loss: -0.8484 - val_iou: 0.7462
# Epoch 40/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8757 - iou: 0.7845 - val_loss: -0.8439 - val_iou: 0.7388
# Epoch 41/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8762 - iou: 0.7853 - val_loss: -0.8476 - val_iou: 0.7440
# Epoch 42/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8693 - iou: 0.7757 - val_loss: -0.8533 - val_iou: 0.7532
# Epoch 43/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8649 - iou: 0.7696 - val_loss: -0.8471 - val_iou: 0.7435
# Epoch 44/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8716 - iou: 0.7788 - val_loss: -0.8496 - val_iou: 0.7467
# Epoch 45/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8758 - iou: 0.7849 - val_loss: -0.8552 - val_iou: 0.7559
# Epoch 46/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8821 - iou: 0.7944 - val_loss: -0.8522 - val_iou: 0.7515
# Epoch 47/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8826 - iou: 0.7950 - val_loss: -0.8601 - val_iou: 0.7624
# Epoch 48/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8807 - iou: 0.7930 - val_loss: -0.8580 - val_iou: 0.7590
# Epoch 49/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8793 - iou: 0.7907 - val_loss: -0.8610 - val_iou: 0.7642
# Epoch 50/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8828 - iou: 0.7956 - val_loss: -0.8640 - val_iou: 0.7690
# Epoch 51/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8824 - iou: 0.7958 - val_loss: -0.8603 - val_iou: 0.7638
# Epoch 52/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8853 - iou: 0.7996 - val_loss: -0.8633 - val_iou: 0.7675
# Epoch 53/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8866 - iou: 0.8016 - val_loss: -0.8508 - val_iou: 0.7495
# Epoch 54/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8879 - iou: 0.8039 - val_loss: -0.8638 - val_iou: 0.7687
# Epoch 55/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8853 - iou: 0.7994 - val_loss: -0.8536 - val_iou: 0.7533
# Epoch 56/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8865 - iou: 0.8019 - val_loss: -0.8626 - val_iou: 0.7679
# Epoch 57/100
# 221/221 [==============================] - 5s 24ms/step - loss: -0.8779 - iou: 0.7906 - val_loss: -0.8522 - val_iou: 0.7494
# Epoch 58/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8733 - iou: 0.7814 - val_loss: -0.8628 - val_iou: 0.7668
# Epoch 59/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8874 - iou: 0.8031 - val_loss: -0.8679 - val_iou: 0.7751
# Epoch 60/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8891 - iou: 0.8058 - val_loss: -0.8659 - val_iou: 0.7718
# Epoch 61/100
# 221/221 [==============================] - 5s 24ms/step - loss: -0.8917 - iou: 0.8100 - val_loss: -0.8617 - val_iou: 0.7660
# Epoch 62/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8927 - iou: 0.8114 - val_loss: -0.8628 - val_iou: 0.7673
# Epoch 63/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8947 - iou: 0.8146 - val_loss: -0.8677 - val_iou: 0.7757
# Epoch 64/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8917 - iou: 0.8099 - val_loss: -0.8626 - val_iou: 0.7672
# Epoch 65/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8858 - iou: 0.8015 - val_loss: -0.8581 - val_iou: 0.7597
# Epoch 66/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8922 - iou: 0.8107 - val_loss: -0.8630 - val_iou: 0.7671
# Epoch 67/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8921 - iou: 0.8106 - val_loss: -0.8592 - val_iou: 0.7623
# Epoch 68/100
# 221/221 [==============================] - 5s 24ms/step - loss: -0.8867 - iou: 0.8033 - val_loss: -0.8648 - val_iou: 0.7707
# Epoch 69/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8896 - iou: 0.8071 - val_loss: -0.8642 - val_iou: 0.7695
# Epoch 70/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8942 - iou: 0.8146 - val_loss: -0.8611 - val_iou: 0.7643
# Epoch 71/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8945 - iou: 0.8148 - val_loss: -0.8696 - val_iou: 0.7781
# Epoch 72/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8918 - iou: 0.8107 - val_loss: -0.8657 - val_iou: 0.7713
# Epoch 73/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8973 - iou: 0.8190 - val_loss: -0.8691 - val_iou: 0.7778
# Epoch 74/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8986 - iou: 0.8211 - val_loss: -0.8689 - val_iou: 0.7765
# Epoch 75/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9010 - iou: 0.8247 - val_loss: -0.8722 - val_iou: 0.7816
# Epoch 76/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8998 - iou: 0.8229 - val_loss: -0.8714 - val_iou: 0.7805
# Epoch 77/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9004 - iou: 0.8239 - val_loss: -0.8756 - val_iou: 0.7877
# Epoch 78/100
# 221/221 [==============================] - 5s 24ms/step - loss: -0.8998 - iou: 0.8228 - val_loss: -0.8678 - val_iou: 0.7752
# Epoch 79/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9006 - iou: 0.8242 - val_loss: -0.8626 - val_iou: 0.7667
# Epoch 80/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9018 - iou: 0.8262 - val_loss: -0.8710 - val_iou: 0.7804
# Epoch 81/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9025 - iou: 0.8273 - val_loss: -0.8733 - val_iou: 0.7837
# Epoch 82/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9035 - iou: 0.8289 - val_loss: -0.8734 - val_iou: 0.7838
# Epoch 83/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9036 - iou: 0.8294 - val_loss: -0.8676 - val_iou: 0.7755
# Epoch 84/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9035 - iou: 0.8291 - val_loss: -0.8722 - val_iou: 0.7826
# Epoch 85/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9019 - iou: 0.8265 - val_loss: -0.8714 - val_iou: 0.7817
# Epoch 86/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8988 - iou: 0.8213 - val_loss: -0.8737 - val_iou: 0.7850
# Epoch 87/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9020 - iou: 0.8268 - val_loss: -0.8722 - val_iou: 0.7820
# Epoch 88/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.8984 - iou: 0.8206 - val_loss: -0.8672 - val_iou: 0.7734
# Epoch 89/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9030 - iou: 0.8283 - val_loss: -0.8716 - val_iou: 0.7812
# Epoch 90/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9028 - iou: 0.8278 - val_loss: -0.8691 - val_iou: 0.7774
# Epoch 91/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9048 - iou: 0.8312 - val_loss: -0.8674 - val_iou: 0.7746
# Epoch 92/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9066 - iou: 0.8342 - val_loss: -0.8730 - val_iou: 0.7836
# Epoch 93/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9076 - iou: 0.8360 - val_loss: -0.8746 - val_iou: 0.7862
# Epoch 94/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9041 - iou: 0.8304 - val_loss: -0.8675 - val_iou: 0.7755
# Epoch 95/100
# 221/221 [==============================] - 5s 24ms/step - loss: -0.9029 - iou: 0.8282 - val_loss: -0.8767 - val_iou: 0.7887
# Epoch 96/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9050 - iou: 0.8319 - val_loss: -0.8700 - val_iou: 0.7778
# Epoch 97/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9047 - iou: 0.8312 - val_loss: -0.8797 - val_iou: 0.7939
# Epoch 98/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9071 - iou: 0.8352 - val_loss: -0.8758 - val_iou: 0.7875
# Epoch 99/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9077 - iou: 0.8360 - val_loss: -0.8765 - val_iou: 0.7892
# Epoch 100/100
# 221/221 [==============================] - 5s 23ms/step - loss: -0.9095 - iou: 0.8390 - val_loss: -0.8738 - val_iou: 0.7849

# %%
y_pred = model_jacard_lr.predict(X_test1,verbose=0)
y_pred_trasholded = y_pred > 0.5

intersection = np.logical_and(y_test1, y_pred_trasholded)
union = np.logical_or(y_test1,y_pred_trasholded)
iou_score = np.sum(intersection)/ np.sum(union)
print ("IoU score is: ",iou_score)
# Out:
# IoU score is:  0.8015323117921386

# %%
History_model_jacard_lr.history.keys()
# Out:
# dict_keys(['loss', 'iou', 'val_loss', 'val_iou'])

# %%
with plt.style.context('Solarize_Light2'):
  plt.plot((History_model_jacard_lr.history['iou']),label='iou', linestyle='-', color='b')
  plt.plot((History_model_jacard_lr.history['val_iou']),label='val_iou', linestyle='-', color='r')
  ax = plt.subplot(111)
  box = ax.get_position()
  ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
  ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
with plt.style.context('Solarize_Light2'):
  plt.plot((History_model_jacard_lr.history['loss']),label='loss', linestyle='-', color='b')
  plt.plot((History_model_jacard_lr.history['val_loss']),label='val_loss', linestyle='-', color='r')
  ax = plt.subplot(111)
  box = ax.get_position()
  ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
  ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
  plt.legend(loc='best')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
preds_test_t = (y_pred > 0.5).astype(np.uint8)

ix = random.randint(0, len(preds_test_t))
plt.figure(figsize=(12,6))
plt.subplot(131)
imshow(X_test1[ix])
plt.title('Orginal Image')
plt.subplot(132)
imshow(np.squeeze(y_test1[ix]))
plt.title('Orginal Mask')
plt.subplot(133)
imshow(np.squeeze(preds_test_t[ix]))
plt.title('Predict Mask')
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
# <function matplotlib.pyplot.show>
